# %% [markdown]
# # Esercizio W14D4

# %%
pip install PyMySQL
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
pip install SQLAlchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python_dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import dotenv
import pandas as pd
from sqlalchemy import create_engine

dotenv.load_dotenv(dotenv_path=".env", override=True)

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

dotenv.load_dotenv(override=True)
conn_string = "mysql+pymysql://" + username + ":" + password + "@" + host + "/" + dbname
db_engine = create_engine(conn_string)

query = "SELECT * FROM dimproduct"
df = pd.read_sql(sql=query, con=db_engine)

# %%
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %% [markdown]
# * 1

# %%
df.columns
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ProductKey                        int64
# ProductAlternateKey              object
# ProductSubcategoryKey           float64
# WeightUnitMeasureCode            object
# SizeUnitMeasureCode              object
# EnglishProductName               object
# SpanishProductName               object
# FrenchProductName                object
# StandardCost                    float64
# FinishedGoodsFlag                 int64
# Color                            object
# SafetyStockLevel                  int64
# ReorderPoint                      int64
# ListPrice                       float64
# Size                             object
# SizeRange                        object
# Weight                          float64
# DaysToManufacture                 int64
# ProductLine                      object
# DealerPrice                     float64
# Class                            object
# Style                            object
# ModelName                        object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=606, step=1)

# %%
df.head()
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
# 1           2             BA-8327                    NaN
# 2           3             BE-2349                    NaN
# 3           4             BE-2908                    NaN
# 4           5             BL-2036                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                  None                None        Adjustable Race
# 1                  None                None           Bearing Ball
# 2                  None                None        BB Ball Bearing
# 3                  None                None  Headset Ball Bearings
# 4                  None                None                  Blade
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
# ...

# %%
df.tail()
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 601                     G                None   ML Bottom Bracket
# 602                     G                None   HL Bottom Bracket
# 603                    LB                  CM  Road-750 Black, 44
# 604                    LB                  CM  Road-750 Black, 48
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 601         Eje de pedalier GM          Axe de pédalier ML         44.95
# ...

# %%
df.sample()
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 152         153             LW-8000                    NaN
#
#     WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 152                  None                None      Lock Washer 3
#
#     SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  \
# 152                                                NaN                  0
#
#      ... ChineseDescription  ArabicDescription  HebrewDescription  \
# 152  ...               None               None               None
#
#      ThaiDescription GermanDescription JapaneseDescription  \
# 152             None              None                None
#
#      TurkishDescription  StartDate EndDate   Status
# 152                None 2003-07-01     NaT  Current
#
# [1 rows x 36 columns]

# %%
df.describe()
# Out:
#        ProductKey  ProductSubcategoryKey  StandardCost  FinishedGoodsFlag  \
# count   606.00000             397.000000    397.000000         606.000000
# mean    303.50000              12.128463    436.823073           0.655116
# min       1.00000               1.000000      0.860000           0.000000
# 25%     152.25000               2.000000     37.120000           0.000000
# 50%     303.50000              13.000000    204.630000           1.000000
# 75%     454.75000              16.000000    660.910000           1.000000
# max     606.00000              37.000000   2171.290000           1.000000
# std     175.08141               9.423328    497.343079           0.475723
#
#        SafetyStockLevel  ReorderPoint    ListPrice       Weight  \
# count        606.000000    606.000000   395.000000   282.000000
# mean         495.201320    371.400990   747.661544    56.193227
# min            4.000000      3.000000     2.290000     2.120000
# ...

# %%
df.nunique()
# Out:
# ProductKey               606
# ProductAlternateKey      504
# ProductSubcategoryKey     37
# WeightUnitMeasureCode      2
# SizeUnitMeasureCode        1
# EnglishProductName       504
# SpanishProductName       238
# FrenchProductName        238
# StandardCost             131
# FinishedGoodsFlag          2
# Color                     10
# SafetyStockLevel           6
# ReorderPoint               6
# ListPrice                119
# Size                      18
# SizeRange                 11
# Weight                   127
# DaysToManufacture          4
# ProductLine                4
# DealerPrice              120
# Class                      3
# Style                      3
# ModelName                119
# LargePhoto                42
# EnglishDescription       114
# FrenchDescription        113
# ChineseDescription       113
# ArabicDescription        113
# HebrewDescription        113
# ThaiDescription          113
# GermanDescription        113
# JapaneseDescription      114
# ...

# %%
df["Color"]
# Out:
# 0         NA
# 1         NA
# 2         NA
# 3         NA
# 4         NA
#        ...
# 601       NA
# 602       NA
# 603    Black
# 604    Black
# 605    Black
# Name: Color, Length: 606, dtype: object

# %%
df.loc[ :, ["ProductKey","ListPrice"] ]
# Out:
#      ProductKey  ListPrice
# 0             1        NaN
# 1             2        NaN
# 2             3        NaN
# 3             4        NaN
# 4             5        NaN
# ..          ...        ...
# 601         602     101.24
# 602         603     121.49
# 603         604     539.99
# 604         605     539.99
# 605         606     539.99
#
# [606 rows x 2 columns]

# %%
df.iloc[1:5, 4:7]
# Out:
#   SizeUnitMeasureCode     EnglishProductName SpanishProductName
# 1                None           Bearing Ball
# 2                None        BB Ball Bearing
# 3                None  Headset Ball Bearings
# 4                None                  Blade

# %%
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
df.describe()
# Out:
#        ProductKey  ProductSubcategoryKey  StandardCost  FinishedGoodsFlag  \
# count   606.00000             397.000000    397.000000         606.000000
# mean    303.50000              12.128463    436.823073           0.655116
# min       1.00000               1.000000      0.860000           0.000000
# 25%     152.25000               2.000000     37.120000           0.000000
# 50%     303.50000              13.000000    204.630000           1.000000
# 75%     454.75000              16.000000    660.910000           1.000000
# max     606.00000              37.000000   2171.290000           1.000000
# std     175.08141               9.423328    497.343079           0.475723
#
#        SafetyStockLevel  ReorderPoint    ListPrice       Weight  \
# count        606.000000    606.000000   395.000000   282.000000
# mean         495.201320    371.400990   747.661544    56.193227
# min            4.000000      3.000000     2.290000     2.120000
# ...

# %% [markdown]
# * 2

# %%
filtro_peso = df.loc[:,"Weight"] > 100
pesi_massimi=df.loc[filtro_peso, "Weight"]
pesi_massimi.shape
# Out:
# (28,)

# %%
pesi_massimi.mean()
# Out:
# 454.42857142857144

# %% [markdown]
# * 3

# %%
filtro_blu= df.loc[:,"Color"] == "Blue"

# %%
costi_blue = df.loc[filtro_blu, "DealerPrice" ]

# %%
costi_blue.shape
# Out:
# (28,)

# %%
costi_blue.max()
# Out:
# 1430.442

# %%
filtro_taglia = df.loc[:, "Size"] == "42"
filtro_peso = df.loc[:, "Weight"] > 10
filtro = filtro_taglia & filtro_peso

costi_filtro = df.loc [filtro, "DealerPrice" ]
costi_filtro.max()
# Out:
# 2039.994

# %%
filtro_taglia = df.loc[:, "Size"] == "42"
filtro_peso = df.loc[:, "Weight"] > 10
filtro_colore = df.loc[:, "Color"] == "Silver"

filtro = filtro_taglia & filtro_peso & filtro_colore
df.loc[filtro, ["StandardCost","EnglishProductName"]]
# Out:
#      StandardCost         EnglishProductName
# 344       1912.15    Mountain-100 Silver, 42
# 353       1117.86    Mountain-200 Silver, 42
# 354       1265.62    Mountain-200 Silver, 42
# 588        419.78  Mountain-400-W Silver, 42
# 591        308.22    Mountain-500 Silver, 42

# %% [markdown]
# # Esercizio W14D4 Parte 2

# %% [markdown]
# * 1

# %%
import pandas as pd

# %%
file_path = "beginner_datasets/iris.csv"
iris = pd.read_csv(file_path)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
file_path = "beginner_datasets/amazon.csv"
amazon = pd.read_csv(file_path)

# %%
amazon
# Out:
#                                               reviewText  Positive
# 0      This is a one of the best apps acording to a b...         1
# 1      This is a pretty good version of the game for ...         1
# 2      this is a really cool game. there are a bunch ...         1
# 3      This is a silly game and can be frustrating, b...         1
# 4      This is a terrific game on any pad. Hrs of fun...         1
# ...                                                  ...       ...
# 19995  this app is fricken stupid.it froze on the kin...         0
# 19996  Please add me!!!!! I need neighbors! Ginger101...         1
# 19997  love it!  this game. is awesome. wish it had m...         1
# 19998  I love love love this app on my side of fashio...         1
# 19999  This game is a rip off. Here is a list of thin...         0
#
# [20000 rows x 2 columns]

# %% [markdown]
# * Valutiamo la dimensione del dataset

# %%
amazon.shape
# Out:
# (20000, 2)

# %% [markdown]
# * Visualizziamo dieci righe a caso;

# %%
amazon.sample(10)
# Out:
#                                               reviewText  Positive
# 19507  Feedly is a great app that can find and organi...         1
# 15335  Works great.  It has LOTS of radio stations an...         1
# 12574  love this app it is a wonderful little app i h...         1
# 2897   I don't know what problems everyone else is co...         1
# 4700   Absolutely loved the game. Easy gameplay, fun,...         1
# 17262  Great app, free app, love my QVC shopping, eas...         1
# 9193   This is cool to be able to watch music videos ...         1
# 3485   I loved this app it was amazing but everytime ...         0
# 6717   wasn't worth the time or energy to upload it, ...         0
# 14305  My 18 month old loves this. She will spend hou...         1

# %% [markdown]
# * Osserviamo quali sono i nomi di colonna;

# %%
amazon.columns
# Out:
# Index(['reviewText', 'Positive'], dtype='object')

# %% [markdown]
# * Il dataset è bilanciato, ovvero, il numero di recensioni positive è uguale a quello delle negative, oppure no?

# %%
pos = amazon.loc[:, "Positive"]
pos
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 19995    0
# 19996    1
# 19997    1
# 19998    1
# 19999    0
# Name: Positive, Length: 20000, dtype: int64

# %%
pos.value_counts()
# Out:
# Positive
# 1    15233
# 0     4767
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
file_path = "beginner_datasets/pokemon.csv"
pokemon = pd.read_csv(file_path)

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
filtro = pokemon.duplicated(subset="#")
filtro.value_counts()
# Out:
# False    721
# True      79
# Name: count, dtype: int64

# %%
filtro2 = pokemon.duplicated()
filtro2.value_counts()
# Out:
# False    800
# Name: count, dtype: int64

# %%
 pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
filtro_duplicati = pokemon.duplicated(subset="#",keep=False)
pokemon.loc[filtro_duplicati]
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 2      3                   Venusaur    Grass  Poison    525  80      82
# 3      3      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 6      6                  Charizard     Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# ..   ...                        ...      ...     ...    ...  ..     ...
# 787  711        GourgeistSuper Size    Ghost   Grass    494  85     100
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon = pokemon.set_index("#")

# %%
pokemon.loc[711]
# Out:
#                       Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 711  GourgeistAverage Size  Ghost  Grass    494  65      90      122       58
# 711    GourgeistSmall Size  Ghost  Grass    494  55      85      122       58
# 711    GourgeistLarge Size  Ghost  Grass    494  75      95      122       58
# 711    GourgeistSuper Size  Ghost  Grass    494  85     100      122       58
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 711       75     84           6      False
# 711       75     99           6      False
# 711       75     69           6      False
# 711       75     54           6      False
